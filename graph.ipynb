# %%
import plotly.graph_objects as go
import pandas as pd
import ccxt

# %%
def fetch_binance_data(symbol='BTC/USDT', timeframe='1d'):
    exchange = ccxt.binance()
    since = exchange.parse8601('2017-01-01T00:00:00Z')
    all_ohlcv = []
    while True:
        ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since=since, limit=1000)
        if not ohlcv:
            break
        all_ohlcv.extend(ohlcv)
        since = ohlcv[-1][0] + 1
    
    df = pd.DataFrame(all_ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['datetime'] = pd.to_datetime(df['timestamp'], unit='ms')
    return df

# %%
def kline(data):
    fig = go.Figure(data=[go.Candlestick(x=data.index,
                    open=data['open'], high=data['high'],
                    low=data['low'], close=data['close'])])
    fig.update_layout(title="K線圖", xaxis_rangeslider_visible=False)
    fig.show()

# %%
# 生成假數據
test_data = pd.DataFrame({
    'open': [100, 102, 105, 103, 101],
    'high': [105, 107, 108, 106, 104],
    'low': [98, 101, 102, 100, 99],
    'close': [102, 106, 104, 101, 100]
}, index=pd.date_range("2024-02-10", periods=5))

# %%
data = fetch_binance_data()
data.set_index('datetime', inplace=True)
kline(data)

# %%
data.head()
# Out:
#                 timestamp     open     high      low    close       volume
# datetime
# 2017-08-17  1502928000000  4261.48  4485.39  4200.74  4285.08   795.150377
# 2017-08-18  1503014400000  4285.08  4371.52  3938.77  4108.37  1199.888264
# 2017-08-19  1503100800000  4108.37  4184.69  3850.00  4139.98   381.309763
# 2017-08-20  1503187200000  4120.98  4211.08  4032.62  4086.29   467.083022
# 2017-08-21  1503273600000  4069.13  4119.62  3911.79  4016.00   691.743060
